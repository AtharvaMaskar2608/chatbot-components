# %%
import pandas as pd

# %%
audio_calls_rating_2 = pd.read_csv("/home/choice/Desktop/chatbot-components/script/audio calls/Shortlisted Calls - 2s.csv")
audio_calls_rating_0 = pd.read_csv("/home/choice/Desktop/chatbot-components/script/audio calls/Shortlisted Calls - 2s.csv")

# %%
audio_calls_rating_0
# Out:
#                                            Unnamed: 0  Sr. No. Caller Name  \
# 0   https://konnect.knowlarity.com/konnect/api/v1/...        1     Deeksha
# 1   https://konnect.knowlarity.com/konnect/api/v1/...        2       sadaf
# 2   https://konnect.knowlarity.com/konnect/api/v1/...        4    abhishek
# 3   https://konnect.knowlarity.com/konnect/api/v1/...        5        Aman
# 4   https://konnect.knowlarity.com/konnect/api/v1/...       93     Deeksha
# 5   https://konnect.knowlarity.com/konnect/api/v1/...       99    abhishek
# 6   https://konnect.knowlarity.com/konnect/api/v1/...      104    abhishek
# 7   https://konnect.knowlarity.com/konnect/api/v1/...      141     Manisha
# 8   https://konnect.knowlarity.com/konnect/api/v1/...      138     Manisha
# 9   https://konnect.knowlarity.com/konnect/api/v1/...      127     Deeksha
# 10  https://konnect.knowlarity.com/konnect/api/v1/...      119     Deeksha
# ...

# %%
call_links_2 = audio_calls_rating_2['Unnamed: 0']
call_links_0 = audio_calls_rating_0['Unnamed: 0']

# %%
len(call_links_0)
# Out:
# 12
